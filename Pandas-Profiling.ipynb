# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
! pip install pandas-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas-profiling) (1.15.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas-profiling) (3.10.1)
# Collecting pydantic>=1.8.1 (from pandas-profiling)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas-profiling) (3.1.5)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas-profiling) (2.2.2)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.4-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas-profiling) (2.32.3)
# Collecting tqdm>=4.48.2 (from pandas-profiling)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas-profiling) (0.13.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Downloading multimethod-2.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (25.1.0)
# Collecting networkx>=2.4 (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: Pillow in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.1)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.8.1->pandas-profiling)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic>=1.8.1->pandas-profiling)
#   Downloading pydantic_core-2.27.2-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from requests>=2.24.0->pandas-profiling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from requests>=2.24.0->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from requests>=2.24.0->pandas-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from requests>=2.24.0->pandas-profiling) (2024.12.14)
# Requirement already satisfied: colorama in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\priyanshu kumar\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.17.0)
# Collecting PyWavelets (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading pywavelets-1.8.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ------------------- -------------------- 2.4/4.7 MB 12.2 MB/s eta 0:00:01
#    ------------------------------------- -- 4.5/4.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 11.0 MB/s eta 0:00:00
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-2.0-py3-none-any.whl (9.8 kB)
# Downloading phik-0.12.4-cp312-cp312-win_amd64.whl (666 kB)
#    ---------------------------------------- 0.0/666.4 kB ? eta -:--:--
#    ---------------------------------------- 666.4/666.4 kB 8.8 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 10.1 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 7.8 MB/s eta 0:00:00
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading pywavelets-1.8.0-cp312-cp312-win_amd64.whl (4.2 MB)
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------- ----------------- 2.4/4.2 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.2/4.2 MB 10.5 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (pyproject.toml): started
#   Building wheel for htmlmin (pyproject.toml): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27172 sha256=f9838f01129e3dd0395277d6d5ccd1ced39b287ff023dde2ef42fdddba321b77
#   Stored in directory: c:\users\priyanshu kumar\appdata\local\pip\cache\wheels\5f\d4\d7\4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# Installing collected packages: htmlmin, tqdm, tangled-up-in-unicode, PyWavelets, pydantic-core, networkx, multimethod, markupsafe, joblib, annotated-types, pydantic, imagehash, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
# Successfully installed PyWavelets-1.8.0 annotated-types-0.7.0 htmlmin-0.1.12 imagehash-4.3.2 joblib-1.1.1 markupsafe-2.1.5 missingno-0.5.2 multimethod-2.0 networkx-3.4.2 pandas-profiling-3.2.0 phik-0.12.4 pydantic-2.10.6 pydantic-core-2.27.2 tangled-up-in-unicode-0.2.0 tqdm-4.67.1 visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.6.1 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas_profiling\profile_report.py:13
#      10 from tqdm.auto import tqdm
#      11 from visions import VisionsTypeset
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.alerts import AlertType
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas_profiling\config.py:5
#       2 from enum import Enum
#       3 from typing import Any, Dict, List, Optional
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       8 def _merge_dictionaries(dict1: dict, dict2: dict) -> dict:
#       9     """
#      10     Recursive merge dictionaries.
#      11
#    (...)
#      14     :return: Merged dictionary
#      15     """
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\__init__.py:412, in __getattr__(attr_name)
#     410 dynamic_attr = _dynamic_imports.get(attr_name)
#     411 if dynamic_attr is None:
# --> 412     return _getattr_migration(attr_name)
#     414 package, module_name = dynamic_attr
#     416 if module_name == '__module__':
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\_migration.py:296, in getattr_migration.<locals>.wrapper(name)
#     294     return import_string(REDIRECT_TO_V1[import_path])
#     295 if import_path == 'pydantic:BaseSettings':
# --> 296     raise PydanticImportError(
#     297         '`BaseSettings` has been moved to the `pydantic-settings` package. '
#     298         f'See https://docs.pydantic.dev/{version_short()}/migration/#basesettings-has-moved-to-pydantic-settings '
#     299         'for more details.'
#     300     )
#     301 if import_path in REMOVED_IN_V2:
#     302     raise PydanticImportError(f'`{import_path}` has been removed in V2.')
#
# PydanticImportError: `BaseSettings` has been moved to the `pydantic-settings` package. See https://docs.pydantic.dev/2.10/migration/#basesettings-has-moved-to-pydantic-settings for more details.
#
# For further information visit https://errors.pydantic.dev/2.10/u/import-error
